# %%
import sys
import os
sys.path.append(os.getcwd())
# Fix path for notebook
notebook_dir = os.path.abspath('.')
if notebook_dir not in sys.path:
    sys.path.append(notebook_dir)

import pandas as pd
from datetime import datetime
import time

# Now imports will work
import config
from src.data_engine import DataRepository
from src.features import FeatureEngineer
from src.strategy import SEPAStrategy
from src.database import DatabaseManager

# %%
data_repo = DataRepository()
db = DatabaseManager()
tickers = data_repo.update_universe()
results = data_repo.update_cache(tickers, force=False, source='fmp')

ticker_data = data_repo.get_batch_data(tickers)
valid_ticker_data = {
    ticker: df for ticker, df in ticker_data.items() 
    if df is not None and len(df) >= 200
}

benchmark_data = data_repo.get_benchmark_data()
feature_engine = FeatureEngineer(benchmark_data=benchmark_data)
strategy = SEPAStrategy(benchmark_data=benchmark_data)

enriched_data = feature_engine.process_universe_batch(valid_ticker_data)
results = strategy.batch_scan_universe(enriched_data, scan_date=None)
# Out:
# INFO:src.database:Database initialized at c:\Users\Hang\PycharmProjects\quantamental\database\trades.db
# INFO:src.data_engine:Fetching S&P 500 universe from SSGA...
# INFO:src.data_engine:Successfully loaded 504 unique tickers
# INFO:src.data_engine:Updating cache for 2/504 tickers...
# INFO:src.data_engine:Using FMP API for batch update...
# INFO:src.data_engine:Processing FMP batch 1/1 (2 tickers)
# ERROR:src.data_engine:FMP API request failed: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/historical-price-full/-,RE?apikey=ijhOTOkHXfjKurcgD8X3ENFPjrnR5MPh
# WARNING:src.data_engine:- not in FMP response
# WARNING:src.data_engine:RE not in FMP response
# INFO:src.data_engine:FMP batch update: 0/2 successful
# ERROR:src.data_engine:FMP API request failed: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/historical-price-full/-?apikey=ijhOTOkHXfjKurcgD8X3ENFPjrnR5MPh
# WARNING:src.data_engine:FMP returned no data for -, falling back to yfinance
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['-']: YFPricesMissingError('possibly delisted; no price data found  (period=2y) (Yahoo error = "No data found, symbol may be delisted")')
# ERROR:src.data_engine:FMP API request failed: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/historical-price-full/RE?apikey=ijhOTOkHXfjKurcgD8X3ENFPjrnR5MPh
# WARNING:src.data_engine:FMP returned no data for RE, falling back to yfinance
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['RE']: YFPricesMissingError('possibly delisted; no price data found  (period=2y) (Yahoo error = "No data found, symbol may be delisted")')
# INFO:src.features:FeatureEngineer initialized in dual-stage mode
# INFO:src.features:Batch processed 500/500 tickers successfully
# INFO:src.strategy:Batch scan: 143 qualifying, 1 new triggers

# %%
qualifying_stocks = results['qualifying_stocks']
new_triggers_today = results['new_triggers']
actual_latest_date = results['summary']['latest_date']

# %%
print(results['qualifying_stocks'])
# Out:
# [{'ticker': 'VMC', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(295.0799865722656), 'rs': np.float64(0.4341454651483668), 'vol_ratio': np.float64(0.4929585085091896), 'atr': np.float64(6.002027703221772), 'is_new_trigger': np.False_, 'signal_strength': 0.0, 'trend_ok': np.True_, 'vcp_ok': True, 'trigger_ok': np.False_}, {'ticker': 'CSCO', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(76.06999969482422), 'rs': np.float64(0.11192031619961319), 'vol_ratio': np.float64(0.7359520360054063), 'atr': np.float64(2.1157133919852122), 'is_new_trigger': np.False_, 'signal_strength': 0.0, 'trend_ok': np.True_, 'vcp_ok': True, 'trigger_ok': np.False_}, {'ticker': 'CSX', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(35.29999923706055), 'rs': np.float64(0.05193620471023522), 'vol_ratio': np.float64(0.5579105651340234), 'atr': np.float64(0.6299991607666016), 'is_new_trigger': np.False_, 'signal_strength': 0.0, 'trend_ok': np.True_, 'vcp_ok': True, 'trigger_ok': np.False_}, {'ticker': 'AXP', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(363.9700012207031), 'rs': np.float64(0.5355020085081759), 'vol_ratio': np.float64(0.6229983217364466), 'atr': np.float64(9.216432843889509), 'is_new_trigger': np.False_, 'signal_strength': 0.0, 'trend_ok': np.True_, 'vcp_ok': True, 'trigger_ok': np.False_}, {'ticker': 'LUV', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(35.060001373291016), 'rs': np.float64(0.051583100504791854), 'vol_ratio': np.float64(0.5124183649775408), 'atr': np.float64(1.2192861012050085), 'is_new_trigger': np.False_, 'signal_strength': 0.0, 'trend_ok': np.True_, 'vcp_ok': True, 'trigger_ok': np.False_}, {'ticker': 'L', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(108.26000213623047), 'rs': np.float64(0.15928084290083305), 'vol_ratio': np.float64(0.664418739724342), 'atr': np.float64(1.4924142020089286), 'is_new_trigger': np.False_, 'signal_strength': 0.0, 'trend_ok': np.True_, 'vcp_ok': True, 'trigger_ok': np.False_}, {'ticker': 'LRCX', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(155.13999938964844), 'rs': np.float64(0.22825447425469947), 'vol_ratio': np.float64(0.7031910322976819), 'atr': np.float64(8.142143249511719), 'is_new_trigger': np.False_, 'signal_strength': 0.0, 'trend_ok': np.True_, 'vcp_ok': True, 'trigger_ok': np.False_}, {'ticker': 'TPR', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(110.69999694824219), 'rs': np.float64(0.16287075997696454), 'vol_ratio': np.float64(0.734736292373094), 'atr': np.float64(3.907141549246652), 'is_new_trigger': np.False_, 'signal_strength': 0.0, 'trend_ok': np.True_, 'vcp_ok': True, 'trigger_ok': np.False_}, {'ticker': 'BK', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(111.38999938964844), 'rs': np.float64(0.16388594719571706), 'vol_ratio': np.float64(0.8738726776172002), 'atr': np.float64(2.3696436200823103), 'is_new_trigger': np.False_, 'signal_strength': 0.0, 'trend_ok': np.True_, 'vcp_ok': True, 'trigger_ok': np.False_}, {'ticker': 'BKR', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(49.529998779296875), 'rs': np.float64(0.07287252723786371), 'vol_ratio': np.float64(0.6571588810684795), 'atr': np.float64(1.4096434456961495), 'is_new_trigger': np.False_, 'signal_strength': 0.0, 'trend_ok': np.True_, 'vcp_ok': True, 'trigger_ok': np.False_}, {'ticker': 'APH', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(138.72000122070312), 'rs': np.float64(0.2040960491930721), 'vol_ratio': np.float64(0.7571272565932695), 'atr': np.float64(5.077142987932477), 'is_new_trigger': np.False_, 'signal_strength': 0.0, 'trend_ok': np.True_, 'vcp_ok': True, 'trigger_ok': np.False_}, {'ticker': 'BAC', 'date': Timestamp('2025-11-26 00:00:00'), 'price': np.float64(52.9900016784668), 'rs': np.float64(0.07796316244333518), 'vol_ratio': np.float64(0.9048384327557252), 'atr': np.float64(1.036914552961077), 'is_new_trigger': np.False_, 'signal_stre ...

# %%
print(results['new_triggers'])
# Out:
# [{'ticker': 'ADI', 'date': Timestamp('2025-11-26 00:00:00'), 'entry_price': np.float64(257.92), 'stop_price': np.float64(237.29), 'target_price': np.float64(319.82), 'risk_pct': 8.0, 'reward_pct': 24.0, 'atr': np.float64(8.38), 'rs': np.float64(0.379472716877171), 'vol_ratio': np.float64(1.4668096521237843), 'signal_strength': 1.0}]
